# %%
pip install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 2.1 MB 995 kB/s eta 0:00:01     |████████████████████▎           | 1.3 MB 1.1 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install psycopg2-binary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipython-sql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql
from sqlalchemy import create_engine

# %%
pip install ipython-sql pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %sql postgresql://postgres:@localhost:5432/customerdb
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# %sql select * from transactions limit 10
# Out:
#  * postgresql://postgres:***@localhost:5432/customerdb
# 10 rows affected.
# [(847545, None, 'ID_017ba29a4d371608fad8313ff1d46c8bb42ef830ee033fc5217d196b049526e06e57ab4b772787f885b0abffeb11e6808f7b3eb050ea5ee3284b8775d70859d0', datetime.datetime(2022, 7, 13, 0, 0), '9317537c2329262b5e19d3e29d23422558e519ca8ff0a8934afc019b97fc714685f4fc0ebc7c8425a8eaa60c4b526940ca6f8e53ffed77ff6f1d61819c2e7460', 1857.56, 1000.0, 11785, 'SAVE', 'internet', '89fe98c0e6ccddcf9a0368507f02773693e01dfeb6911c3987c799aa879f946b76ae958b973d03df1b9451316f27619a20b47ab80c6663fb6067bcb51ab35b98', None),
# ...

# %%
# %%sql
# SELECT i.income_group_desc, count (distinct(c.customer_identifier)) AS customers, count(t.customer_identifier) as transactions
# FROM customers c
# JOIN income_group as i
# ON i.income_group_code = c.income_group_code
# JOIN transactions t
# ON c.customer_identifier = t.customer_identifier
# GROUP BY i.income_group_code, i.income_group_desc
# OFFSET 1 ROW
# Out:
#  * postgresql://postgres:***@localhost:5432/customerdb
# 21 rows affected.
# [('R 0 - 499', 62, 14994),
#  ('R500 - 999', 30, 2496),
#  ('R1,000 - 1,999', 96, 8319),
#  ('R2,000 - 2,999', 82, 5889),
#  ('R3,000 - 3,999', 150, 13395),
#  ('R4,000 - 4,999', 438, 38242),
#  ('R5,000 - 5,999', 373, 40719),
#  ('R6,000 - 6,999', 357, 41316),
#  ('R7,000 - 7,999', 331, 47822),
#  ('R8,000 - 8,999', 305, 47663),
#  ('R9,000 - 9,999', 200, 31597),
#  ('R10,000 - 11,999', 438, 69661),
#  ('R12,000 - 14,999', 459, 84208),
#  ('R15,000 - 19,999', 597, 131996),
#  ('R20,000 - 24,999', 451, 105093),
#  ('R25,000 - 33,999', 403, 90633),
#  ('R34,000 - 41,999', 186, 42675),
#  ('R42,000 - 62,999', 115, 23648),
#  ('R63,000 - 84,999', 48, 6101),
#  ('R85,000 - 124,999', 15, 824),
#  ('R125,000+', 6, 117)]

# %%
# %%sql
# SELECT
# EXTRACT(MONTH FROM record_date) AS transaction_month,
# i.income_group_desc, AVG(t.account_balance) AS average_account_balance
# FROM customers c
# JOIN income_group i
# ON i.income_group_code = c.income_group_code
# JOIN transactions t
# ON c.customer_identifier = t.customer_identifier
# GROUP BY i.income_group_code, i.income_group_desc, transaction_month
# order by transaction_month
# Out:
#  * postgresql://postgres:***@localhost:5432/customerdb
# 258 rows affected.
# [(Decimal('1'), 'NOT SUPPLIED', 1740.2145714285714),
#  (Decimal('1'), 'R 0 - 499', 5353.412958387518),
#  (Decimal('1'), 'R500 - 999', 6765.311477663229),
#  (Decimal('1'), 'R1,000 - 1,999', 6061.424959677417),
#  (Decimal('1'), 'R2,000 - 2,999', 4023.5963103953145),
#  (Decimal('1'), 'R3,000 - 3,999', 3091.1025121555963),
#  (Decimal('1'), 'R4,000 - 4,999', 2416.466593130411),
#  (Decimal('1'), 'R5,000 - 5,999', 2913.652536143097),
#  (Decimal('1'), 'R6,000 - 6,999', 2511.2743612552563),
#  (Decimal('1'), 'R7,000 - 7,999', 4428.129973850518),
#  (Decimal('1'), 'R8,000 - 8,999', 2930.9554196113068),
#  (Decimal('1'), 'R9,000 - 9,999', 4399.920516556294),
#  (Decimal('1'), 'R10,000 - 11,999', 4191.134660796764),
#  (Decimal('1'), 'R12,000 - 14,999', 4934.329666708121),
#  (Decimal('1'), 'R15,000 - 19,999', 5192.199505811871),
#  (Decimal('1'), 'R20,000 - 24,999', 6312.187069802886),
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine('postgresql://postgres:polpol@localhost:5430/customerdb')
query = ""
SELECT i.descript, COUNT(c.cust_id) AS customer_count, COUNT(t.cust_id) AS transaction_count
    FROM customers c
        JOIN income_group i ON i.code = c.code
        JOIN transaction t ON c.cust_id = t.cust_id
        GROUP BY i.code, i.descript
""

df = pd.read_sql(result, engine)
df
# Out:
#   Cell In[12], line 6
#     SELECT i.descript, COUNT(c.cust_id) AS customer_count, COUNT(t.cust_id) AS transaction_count
#            ^
# SyntaxError: invalid syntax
